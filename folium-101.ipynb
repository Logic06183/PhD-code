# %% [markdown]
# # Folium 101
#
# Importing libraries

# %%
import pandas as pd
import folium

# %% [markdown]
# Our first map

# %%
world = folium.Map(
    zoom_start=2,
    location=[13.133932434766733, 16.103938729508073])
world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
world.save('maps_htmls/world_empty.html')

# %% [markdown]
# ## Marking places
#
# Reading data

# %%
cities = pd.read_excel(r"C:\Users\cparker\OneDrive - WRHI\Desktop\Data\Maps\PP5.xlsx")
print(cities.shape)
cities.head(3)
# Out:
# (43, 12)
#                                       Institution        Project  Country  \
# 0  London School of Hygiene and Tropical Medicine  High Horizons      NaN
# 1                                        Wits RHI  High Horizons      NaN
# 2                                 Lund University  High Horizons      NaN
#
#    City  latitude   longitude  location        Country2        City 2  \
# 0   NaN  51.500152  -0.126236        20  United Kingdom        London
# 1   NaN -26.201452  28.045488        20    South Africa  Johannesburg
# 2   NaN      59.25  16.667000        20          Sweden     Stockholm
#
#    Carbon dioxide emissions Continent  \
# 0                379024.787        EU
# 1                476643.994       AFR
# 2                 43252.265        EU
#
#                                              Website
# 0                                                NaN
# 1  https://www.wrhi.ac.za/expertise/detail/heat_c...
# 2                                                NaN

# %%
import mitosheet
mitosheet.sheet(cities.head(3), view_df=True)
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-990174ce-6eae-444c-bbb3-ce599ba4ef44", "code": {"imports…

# %%
w_cities = pd.read_csv(r"C:\Users\cparker\OneDrive - WRHI\Desktop\Data\Maps\worldcities.csv")
print(w_cities.shape)
w_cities.head(3)
# Out:
# (42905, 11)
#       city city_ascii      lat       lng    country iso2 iso3 admin_name  \
# 0    Tokyo      Tokyo  35.6839  139.7744      Japan   JP  JPN      Tōkyō
# 1  Jakarta    Jakarta  -6.2146  106.8451  Indonesia   ID  IDN    Jakarta
# 2    Delhi      Delhi  28.6667   77.2167      India   IN  IND      Delhi
#
#    capital  population          id
# 0  primary  39105000.0  1392685764
# 1  primary  35362000.0  1360771077
# 2    admin  31870000.0  1356872604

# %%
import mitosheet
mitosheet.sheet(w_cities.head(3), view_df=True)
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-901e3d24-6dbf-48d6-9e10-d6c562716bc8", "code": {"imports…

# %%
import mitosheet
mitosheet.sheet(w_cities, view_df=True)
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-8b48b4c5-f79e-4803-9b89-11d3be318258", "code": {"imports…

# %%
from mitosheet import *; register_analysis('UUID-48cca86f-5473-4d14-84d8-f7e9a13828df')
    
# Imported cities.csv
import pandas as pd
cities = pd.read_csv(r'cities.csv')

# Imported C:\Users\cparker\OneDrive - WRHI\Desktop\Data\Maps\PP5.xlsx
import pandas as pd
sheet_df_dictonary = pd.read_excel(r'C:\Users\cparker\OneDrive - WRHI\Desktop\Data\Maps\PP5.xlsx', engine='openpyxl', sheet_name=['Sheet1'], skiprows=0)
Sheet1 = sheet_df_dictonary['Sheet1']

# Merged Sheet1 and cities
Sheet1_tmp = Sheet1.drop(['Institution', 'Continent', 'City', 'location', 'Country', 'Website', 'Country2', 'latitude ', 'Carbon dioxide emissions', 'Project'], axis=1)
df4 = Sheet1_tmp.merge(cities, left_on=['longitude'], right_on=['longitude'], how='left', suffixes=['_Sheet1', '_cities'])

# Deleted dataframe cities
del cities

# Merged Sheet1 and w_cities
temp_df = w_cities.drop_duplicates(subset='city') # Remove duplicates so lookup merge only returns first match
Sheet1_tmp = Sheet1.drop(['longitude', 'Continent', 'location', 'City', 'Country', 'Website', 'Country2', 'latitude ', 'Carbon dioxide emissions'], axis=1)
df3 = Sheet1_tmp.merge(temp_df, left_on=['City 2'], right_on=['city'], how='left', suffixes=['_Sheet1', '_w_cities'])

# Renamed df3 to P_Cities
P_Cities = df3

# %%
df3.head()
# Out:
#                                       Institution        Project  \
# 0  London School of Hygiene and Tropical Medicine  High Horizons
# 1                                        Wits RHI  High Horizons
# 2                                 Lund University  High Horizons
# 3                            Karolinska Institute  High Horizons
# 4                   the World Health Organization  High Horizons
#
#          City 2          city    city_ascii      lat      lng         country  \
# 0        London        London        London  51.5072  -0.1275  United Kingdom
# 1  Johannesburg  Johannesburg  Johannesburg -26.2044  28.0416    South Africa
# 2     Stockholm     Stockholm     Stockholm  59.3294  18.0686          Sweden
# 3     Stockholm     Stockholm     Stockholm  59.3294  18.0686          Sweden
# 4        Geneva        Geneva        Geneva  46.2000   6.1500     Switzerland
#
#   iso2 iso3       admin_name  capital  population            id
# ...

# %%
import mitosheet
mitosheet.sheet(df3, view_df=True)
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-8b56df24-ab74-4877-b7ba-7d57e8b5cc8b", "code": {"imports…

# %%
import mitosheet
mitosheet.sheet(df3, view_df=True)
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-894a659b-7175-46fd-a1d5-c9afa1a97e58", "code": {"imports…

# %%
import mitosheet
mitosheet.sheet(df3, view_df=True)
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-4fa5a265-b4a2-44cc-bb1f-eef1e6876ffc", "code": {"imports…

# %%
from mitosheet import *; register_analysis('UUID-96bbb5b7-2de0-4266-9294-679cdb5adeb3')
    
# Deleted column City 2 from df3
df3.drop(['City 2'], axis=1, inplace=True)

# Set column city at index 41 in df3 to Michigan
df3.at[41, 'city'] = "Michigan"

# Set column city at index 17 in df3 to Tartu
df3.at[17, 'city'] = "Tartu"

# Set column city_ascii at index 17 in df3 to Tartu
df3.at[17, 'city_ascii'] = "Tartu"

# Set column country at index 17 in df3 to Estonia
df3.at[17, 'country'] = "Estonia"

# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
import geopandas as gpd
#import pandas as pd
#import geoplot as gplt
#import geoplot.crs as gcrs
#import contextily as ctx
#from cartopy import crs as ccrs
import matplotlib.pyplot as plt
import folium

# %%
df3.head()
# Out:
#                                       Institution        Project  \
# 0  London School of Hygiene and Tropical Medicine  High Horizons
# 1                                        Wits RHI  High Horizons
# 2                                 Lund University  High Horizons
# 3                            Karolinska Institute  High Horizons
# 4                   the World Health Organization  High Horizons
#
#            city    city_ascii      lat      lng         country iso2 iso3  \
# 0        London        London  51.5072  -0.1275  United Kingdom   GB  GBR
# 1  Johannesburg  Johannesburg -26.2044  28.0416    South Africa   ZA  ZAF
# 2     Stockholm     Stockholm  59.3294  18.0686          Sweden   SE  SWE
# 3     Stockholm     Stockholm  59.3294  18.0686          Sweden   SE  SWE
# 4        Geneva        Geneva  46.2000   6.1500     Switzerland   CH  CHE
#
#         admin_name  capital  population            id
# 0  London, City of  primary  11120000.0  1.826646e+09
# ...

# %%
import mitosheet
mitosheet.sheet(df3, view_df=True)
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-b7a5228d-73f1-4b63-af2e-e2f530002b79", "code": {"imports…

# %%
import mitosheet
mitosheet.sheet(df3, view_df=True)
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-bc26734e-3e18-4eda-85c2-aa8543111d1d", "code": {"imports…

# %% [markdown]
# Marking some cities in the map

# %%
from geopandas import GeoDataFrame
from shapely.geometry import Point

geometry = [Point(xy) for xy in zip(df3.lng, df3.lat)]
df3 = df3.drop(['lng', 'lat'], axis=1)
gdf = GeoDataFrame(df3, crs="EPSG:4326", geometry=geometry)

# %%
df3
# Out:
#                                           Institution        Project  \
# 0      London School of Hygiene and Tropical Medicine  High Horizons
# 1                                            Wits RHI  High Horizons
# 2                                     Lund University  High Horizons
# 3                                Karolinska Institute  High Horizons
# 4                       the World Health Organization  High Horizons
# 5                     Technical University of Denmark  High Horizons
# 6                                  University of Graz  High Horizons
# 7                             Aga Khan Health Service  High Horizons
# 8                             Aga Khan Health Service  High Horizons
# 9   Centre for Sexual Health and HIV AIDS Research...  High Horizons
# 10                                University of Ghent  High Horizons
# 11             Cicero Senter Klimaforskning Stiftelse          ENBEL
# 12                                           Wits RHI          ENBEL
# ...

# %%
import mitosheet
mitosheet.sheet(df3, view_df=True)
# Out:
# C:\Users\cparker\Anaconda3\lib\site-packages\pandas\io\json\_json.py:175: ShapelyDeprecationWarning: The 'array_interface_base' property is deprecated and will be removed in Shapely 2.0.
#   return dumps(
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# ...

# %%
import mitosheet
mitosheet.sheet(df3, view_df=True)

# %%
gdf.head()

# %%
# determining the name of the file
file_name = 'gdf.xlsx'
  
# saving the excel
gdf.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')

# %%
import mitosheet
mitosheet.sheet(gdf, view_df=True)

# %%
import mitosheet
mitosheet.sheet(gdf, view_df=True)

# %%
import mitosheet
mitosheet.sheet(gdf, view_df=True)

# %%
# read in example geodataframe using geopandas datasets
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.head()

# %%
world.plot(figsize=(15, 10));

# %%
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))[197:]
cities.tail()

# %%
# plot cities and annotate
# plt.subplots creates a figure and a set of subplots where subplots defaults to 1
fig, ax = plt.subplots(figsize=(15, 10))
# ax (axes) is the area/subplot on which to draw the plot
world.plot(ax=ax, color='grey')
gdf.plot(ax=ax, color='blue');
#for x, y, label in zip(gdf.geometry.x, gdf.geometry.y, gdf.admin_name):
    # xytext is similar to offset
    #ax.annotate(label, xy=(x, y), xytext=(3, 3), textcoords='offset points', size=16, color='blue')

# %%
# plot points where marker size is based on data column (using pandas dataframe converted to geodataframe)
fig, ax = plt.subplots(figsize=(15, 10))
world.plot(ax=ax)
tb_gdf.plot(ax=ax, color='orange', markersize=tb_gdf.Height, alpha=0.5, edgecolor='k');
fig.suptitle('Tallest Buildings', y=0.85, fontsize=24);

# %% [markdown]
# Let's add all cities I've been to to the map

# %%
world_all_cities = folium.Map(
    zoom_start=2,
    location=[13.133932434766733, 16.103938729508073]
)

for _, city in cities.iterrows():
    folium.Marker(
        location=[city['latitude'], city['longitude']],
    ).add_to(world_all_cities)

world_all_cities

# %%
world_all_cities.save('maps_htmls/world_all_cities.html')

# %% [markdown]
# ## Adding information to markers
# Using `popup` and `tooltip`

# %%
world_all_cities_popup = folium.Map(
    zoom_start=2,
    location=[13.133932434766733, 16.103938729508073]
)

for _, city in cities.iterrows():
    folium.Marker(
        location=[city['latitude'], city['longitude']],
        popup=city['name'],
    ).add_to(world_all_cities_popup)
    
world_all_cities_popup

# %%
world_all_cities_popup.save('maps_htmls/world_all_cities_popup.html')

# %%
world_all_cities_tooltip = folium.Map(
    zoom_start=2,
    location=[13.133932434766733, 16.103938729508073]
)

for _, city in cities.iterrows():
    folium.Marker(
        location=[city['latitude'], city['longitude']],
        popup=city['name'],
        tooltip=city['name'],
    ).add_to(world_all_cities_tooltip)
    
world_all_cities_tooltip

# %%
world_all_cities_tooltip.save('maps_htmls/world_all_cities_tooltip.html')

# %% [markdown]
# Looking closer into the dataset

# %%
cities.head(3)

# %%
cities.tail(3)

# %% [markdown]
# ## Coloring markers
#
# **Feature engineering**: creating a feature for coloring the markers

# %%
def select_marker_color(row):
    if row['lived'] == 'yes':
        return 'pink'
    elif row['lived'] == 'no' and row['visited'] == 'yes':
        return 'purple'
    return 'blue'

# %%
cities['colors'] = cities.apply(select_marker_color, axis=1)
cities.head(3)

# %% [markdown]
# Visualizing colored markers

# %%
world_all_cities_colored = folium.Map(
    zoom_start=2,
    location=[13.133932434766733, 16.103938729508073]
)

for _, city in cities.iterrows():
    folium.Marker(
        location=[city['latitude'], city['longitude']],
        popup=city['name'],
        tooltip=city['name'],
        icon=folium.Icon(color=city['colors'], prefix='fa', icon='circle')
    ).add_to(world_all_cities_colored)
    
world_all_cities_colored

# %%
world_all_cities_colored.save('maps_htmls/world_all_cities_colored.html')
