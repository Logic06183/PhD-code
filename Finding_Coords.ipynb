# %%
# Import pandas package
import pandas as pd
import numpy as np
	
# Define a dictionary containing data
data = pd.read_excel(r"C:\Users\cparker\OneDrive - WRHI\Desktop\Data\Maps\Mito2.xlsx")
	
# Convert the dictionary into DataFrame
df = pd.DataFrame(data)
	
# Observe the result
df
# Out:
#                                           Institution        Project  \
# 0      London School of Hygiene and Tropical Medicine  High Horizons
# 1                                            Wits RHI  High Horizons
# 2                                     Lund University  High Horizons
# 3                                Karolinska Institute  High Horizons
# 4                       the World Health Organization  High Horizons
# 5                     Technical University of Denmark  High Horizons
# 6                                  University of Graz  High Horizons
# 7                             Aga Khan Health Service  High Horizons
# 8                             Aga Khan Health Service  High Horizons
# 9   Centre for Sexual Health and HIV AIDS Research...  High Horizons
# 10                                University of Ghent  High Horizons
# 11             Cicero Senter Klimaforskning Stiftelse          ENBEL
# 12                                           Wits RHI          ENBEL
# 13     London School of Hygiene and Tropical Medicine          ENBEL
# 14                                 University of Graz          ENBEL
# 15                      Azienda Sanitaria Locale Roma          ENBEL
# 16                       Folkehelseinstituttet Norway          ENBEL
# 17               Royal College of Surgeons in Ireland          ENBEL
# 18                    Health And Environment Alliance          ENBEL
# 19                  The Netherlands Red Cross Society          ENBEL
# 20                                Aga Khan University          ENBEL
# 21                           Université Paul Sabatier          ENBEL
# 22                           University of Gothenburg          ENBEL
# 23                                 Ilmatieteen Laitos          ENBEL
# 24                             University of Botswana          ENBEL
# 25                               Karolinska Institute        CHAMNHA
# 26             South African Medical Research Council        CHAMNHA
# 27                                University of Leeds        CHAMNHA
# 28                                 University of Oslo        CHAMNHA
# 29                           University of Washington        CHAMNHA
# 30                                           Wits RHI        CHAMNHA
# 31                                Aga Khan University        CHAMNHA
# 32                                           Wits RHI          HE2AT
# 33  Centre for Sexual Health and HIV AIDS Research...          HE2AT
# 34                                IBM Research Africa          HE2AT
# 35                           University of Washington          HE2AT
# 36                            University of Cape Town          HE2AT
# 37                  University Peleforo Gon Coulibalu          HE2AT
# 38                             University of Michigan          HE2AT
# 39     London School of Hygiene and Tropical Medicine        CHAMNHA
#
#           Country2         City 2  Carbon dioxide emissions Continent  \
# 0   United Kingdom         London                379024.787        EU
# 1     South Africa   Johannesburg                476643.994       AFR
# 2           Sweden      Stockholm                 43252.265        EU
# 3           Sweden      Stockholm                 43252.265        EU
# 4      Switzerland         Geneva                 34477.134        EU
# 5          Denmark     Copenhagen                 31785.556        EU
# 6          Austria           Graz                 61447.919        EU
# 7            Kenya        Nairobi                 17909.628       AFR
# 8         Tanzania  Dar es Salaam                 11972.755       AFR
# 9         Zimbabwe         Harare                 10982.665       AFR
# 10         Belgium          Ghent                 96889.474       AFR
# 11          Norway           Oslo                 41022.729        EU
# 12    South Africa   Johannesburg                476643.994       AFR
# 13  United Kingdom         London                379024.787        EU
# 14         Austria           Graz                 61447.919        EU
# 15           Italy           Rome                320411.459        EU
# 16          Norway           Oslo                 41022.729        EU
# 17         Ireland         Dublin                 37711.428        EU
# 18         Belgium       Brussels                 96889.474        EU
# 19         Holland      Amsterdam                170779.524        EU
# 20           Kenya        Nairobi                 17909.628       AFR
# 21          France          Paris                303275.568        EU
# 22          Sweden     Gothenburg                 43252.265        EU
# 23         Finland           Oslo                 45870.503        EU
# 24        Botswana       Gaborone                  6340.243       AFR
# 25          Sweden      Stockholm                 43252.265        EU
# 26    South Africa      Cape Town                476643.994       AFR
# 27  United Kingdom          Leeds                379024.787        EU
# 28          Norway           Oslo                 41022.729        EU
# 29   United States        Seattle               5006302.077        US
# 30    South Africa   Johannesburg                476643.994       AFR
# 31           Kenya        Nairobi                 17909.628       AFR
# 32    South Africa   Johannesburg                476643.994       AFR
# 33        Zimbabwe         Harare                 10982.665       AFR
# 34    South Africa   Johannesburg                476643.994       AFR
# 35   United States        Seattle               5006302.077        US
# 36    South Africa      Cape Town                476643.994       AFR
# 37   Côte d'Ivoire        Abidjan                  9673.546       AFR
# 38   United States      Ann Arbor               5006302.077        US
# 39  United Kingdom         London                379024.787        EU
#
#        city_ascii      lat       lng  population
# 0          London  51.5072   -0.1275    11120000
# 1    Johannesburg -26.2044   28.0416     4434827
# 2       Stockholm  59.3294   18.0686      975819
# 3       Stockholm  59.3294   18.0686      975819
# 4          Geneva  46.2000    6.1500      201818
# 5      Copenhagen  55.6805   12.5615     1085000
# 6            Graz  47.0708   15.4386      289440
# 7         Nairobi  -1.2864   36.8172     5545000
# 8   Dar es Salaam  -6.8000   39.2833     7461000
# 9          Harare -17.8292   31.0522     2150000
# 10          Ghent  42.3120  -73.6509        5132
# 11           Oslo  59.9111   10.7528      693494
# 12   Johannesburg -26.2044   28.0416     4434827
# 13         London  51.5072   -0.1275    11120000
# 14           Graz  47.0708   15.4386      289440
# 15           Rome  41.8931   12.4828     2872800
# 16           Oslo  59.9111   10.7528      693494
# 17         Dublin  53.3497   -6.2603      553165
# 18       Brussels  50.8353    4.3314     1743000
# 19      Amsterdam  52.3667    4.8833      862965
# 20        Nairobi  -1.2864   36.8172     5545000
# 21          Paris  48.8566    2.3522    11027000
# 22     Gothenburg  57.6717   11.9810      604829
# 23           Oslo  59.9111   10.7528      693494
# 24       Gaborone -24.6569   25.9086      231626
# 25      Stockholm  59.3294   18.0686      975819
# 26      Cape Town -33.9250   18.4250      433688
# 27          Leeds  53.7997   -1.5492      789194
# 28           Oslo  59.9111   10.7528      693494
# 29        Seattle  47.6211 -122.3244     3789215
# 30   Johannesburg -26.2044   28.0416     4434827
# 31        Nairobi  -1.2864   36.8172     5545000
# 32   Johannesburg -26.2044   28.0416     4434827
# 33         Harare -17.8292   31.0522     2150000
# 34   Johannesburg -26.2044   28.0416     4434827
# 35        Seattle  47.6211 -122.3244     3789215
# 36      Cape Town -33.9250   18.4250      433688
# 37        Abidjan   5.3364   -4.0267     4980000
# 38      Ann Arbor  42.2755  -83.7312      322267
# 39         London  51.5072   -0.1275    11120000

# %%
from geopy.exc import GeocoderTimedOut
from geopy.geocoders import Nominatim

# declare an empty list to store
# latitude and longitude of values
# of city column
longitude = []
latitude = []

# function to find the coordinate
# of a given city
def findGeocode(city):
	
	# try and catch is used to overcome
	# the exception thrown by geolocator
	# using geocodertimedout
	try:
		
		# Specify the user_agent as your
		# app name it should not be none
		geolocator = Nominatim(user_agent="your_app_name")
		
		return geolocator.geocode(city)
	
	except GeocoderTimedOut:
		
		return findGeocode(city)	

# each value from city column
# will be fetched and sent to
# function find_geocode
for i in (df["City 2"]):
	
	if findGeocode(i) != None:
		
		loc = findGeocode(i)
		
		# coordinates returned from
		# function is stored into
		# two separate list
		latitude.append(loc.latitude)
		longitude.append(loc.longitude)
	
	# if coordinate for a city not
	# found, insert "NaN" indicating
	# missing value
	else:
		latitude.append(np.nan)
		longitude.append(np.nan)

# %%
# now add this column to dataframe
df["Longitude"] = longitude
df["Latitude"] = latitude

df
# Out:
#                                           Institution        Project  \
# 0      London School of Hygiene and Tropical Medicine  High Horizons
# 1                                            Wits RHI  High Horizons
# 2                                     Lund University  High Horizons
# 3                                Karolinska Institute  High Horizons
# 4                       the World Health Organization  High Horizons
# 5                     Technical University of Denmark  High Horizons
# 6                                  University of Graz  High Horizons
# 7                             Aga Khan Health Service  High Horizons
# 8                             Aga Khan Health Service  High Horizons
# 9   Centre for Sexual Health and HIV AIDS Research...  High Horizons
# 10                                University of Ghent  High Horizons
# 11             Cicero Senter Klimaforskning Stiftelse          ENBEL
# 12                                           Wits RHI          ENBEL
# 13     London School of Hygiene and Tropical Medicine          ENBEL
# 14                                 University of Graz          ENBEL
# 15                      Azienda Sanitaria Locale Roma          ENBEL
# 16                       Folkehelseinstituttet Norway          ENBEL
# 17               Royal College of Surgeons in Ireland          ENBEL
# 18                    Health And Environment Alliance          ENBEL
# 19                  The Netherlands Red Cross Society          ENBEL
# 20                                Aga Khan University          ENBEL
# 21                           Université Paul Sabatier          ENBEL
# 22                           University of Gothenburg          ENBEL
# 23                                 Ilmatieteen Laitos          ENBEL
# 24                             University of Botswana          ENBEL
# 25                               Karolinska Institute        CHAMNHA
# 26             South African Medical Research Council        CHAMNHA
# 27                                University of Leeds        CHAMNHA
# 28                                 University of Oslo        CHAMNHA
# 29                           University of Washington        CHAMNHA
# 30                                           Wits RHI        CHAMNHA
# 31                                Aga Khan University        CHAMNHA
# 32                                           Wits RHI          HE2AT
# 33  Centre for Sexual Health and HIV AIDS Research...          HE2AT
# 34                                IBM Research Africa          HE2AT
# 35                           University of Washington          HE2AT
# 36                            University of Cape Town          HE2AT
# 37                  University Peleforo Gon Coulibalu          HE2AT
# 38                             University of Michigan          HE2AT
# 39     London School of Hygiene and Tropical Medicine        CHAMNHA
#
#           Country2         City 2  Carbon dioxide emissions Continent  \
# 0   United Kingdom         London                379024.787        EU
# 1     South Africa   Johannesburg                476643.994       AFR
# 2           Sweden      Stockholm                 43252.265        EU
# 3           Sweden      Stockholm                 43252.265        EU
# 4      Switzerland         Geneva                 34477.134        EU
# 5          Denmark     Copenhagen                 31785.556        EU
# 6          Austria           Graz                 61447.919        EU
# 7            Kenya        Nairobi                 17909.628       AFR
# 8         Tanzania  Dar es Salaam                 11972.755       AFR
# 9         Zimbabwe         Harare                 10982.665       AFR
# 10         Belgium          Ghent                 96889.474       AFR
# 11          Norway           Oslo                 41022.729        EU
# 12    South Africa   Johannesburg                476643.994       AFR
# 13  United Kingdom         London                379024.787        EU
# 14         Austria           Graz                 61447.919        EU
# 15           Italy           Rome                320411.459        EU
# 16          Norway           Oslo                 41022.729        EU
# 17         Ireland         Dublin                 37711.428        EU
# 18         Belgium       Brussels                 96889.474        EU
# 19         Holland      Amsterdam                170779.524        EU
# 20           Kenya        Nairobi                 17909.628       AFR
# 21          France          Paris                303275.568        EU
# 22          Sweden     Gothenburg                 43252.265        EU
# 23         Finland           Oslo                 45870.503        EU
# 24        Botswana       Gaborone                  6340.243       AFR
# 25          Sweden      Stockholm                 43252.265        EU
# 26    South Africa      Cape Town                476643.994       AFR
# 27  United Kingdom          Leeds                379024.787        EU
# 28          Norway           Oslo                 41022.729        EU
# 29   United States        Seattle               5006302.077        US
# 30    South Africa   Johannesburg                476643.994       AFR
# 31           Kenya        Nairobi                 17909.628       AFR
# 32    South Africa   Johannesburg                476643.994       AFR
# 33        Zimbabwe         Harare                 10982.665       AFR
# 34    South Africa   Johannesburg                476643.994       AFR
# 35   United States        Seattle               5006302.077        US
# 36    South Africa      Cape Town                476643.994       AFR
# 37   Côte d'Ivoire        Abidjan                  9673.546       AFR
# 38   United States      Ann Arbor               5006302.077        US
# 39  United Kingdom         London                379024.787        EU
#
#        city_ascii      lat       lng  population   Longitude   Latitude
# 0          London  51.5072   -0.1275    11120000   -0.127647  51.507322
# 1    Johannesburg -26.2044   28.0416     4434827   28.049722 -26.205000
# 2       Stockholm  59.3294   18.0686      975819   18.071093  59.325117
# 3       Stockholm  59.3294   18.0686      975819   18.071093  59.325117
# 4          Geneva  46.2000    6.1500      201818    6.146601  46.201756
# 5      Copenhagen  55.6805   12.5615     1085000   12.570072  55.686724
# 6            Graz  47.0708   15.4386      289440   15.438279  47.070868
# 7         Nairobi  -1.2864   36.8172     5545000   36.817245  -1.283253
# 8   Dar es Salaam  -6.8000   39.2833     7461000   39.280358  -6.816084
# 9          Harare -17.8292   31.0522     2150000   31.045686 -17.831773
# 10          Ghent  42.3120  -73.6509        5132    3.725012  51.053829
# 11           Oslo  59.9111   10.7528      693494   10.738970  59.913330
# 12   Johannesburg -26.2044   28.0416     4434827   28.049722 -26.205000
# 13         London  51.5072   -0.1275    11120000   -0.127647  51.507322
# 14           Graz  47.0708   15.4386      289440   15.438279  47.070868
# 15           Rome  41.8931   12.4828     2872800   12.482932  41.893320
# 16           Oslo  59.9111   10.7528      693494   10.738970  59.913330
# 17         Dublin  53.3497   -6.2603      553165   -6.260273  53.349764
# 18       Brussels  50.8353    4.3314     1743000    4.351697  50.846557
# 19      Amsterdam  52.3667    4.8833      862965    4.893604  52.372760
# 20        Nairobi  -1.2864   36.8172     5545000   36.817245  -1.283253
# 21          Paris  48.8566    2.3522    11027000    2.320041  48.858890
# 22     Gothenburg  57.6717   11.9810      604829   11.967017  57.707233
# 23           Oslo  59.9111   10.7528      693494   10.738970  59.913330
# 24       Gaborone -24.6569   25.9086      231626   25.908847 -24.658136
# 25      Stockholm  59.3294   18.0686      975819   18.071093  59.325117
# 26      Cape Town -33.9250   18.4250      433688   18.417396 -33.928992
# 27          Leeds  53.7997   -1.5492      789194   -1.543794  53.797418
# 28           Oslo  59.9111   10.7528      693494   10.738970  59.913330
# 29        Seattle  47.6211 -122.3244     3789215 -122.330062  47.603832
# 30   Johannesburg -26.2044   28.0416     4434827   28.049722 -26.205000
# 31        Nairobi  -1.2864   36.8172     5545000   36.817245  -1.283253
# 32   Johannesburg -26.2044   28.0416     4434827   28.049722 -26.205000
# 33         Harare -17.8292   31.0522     2150000   31.045686 -17.831773
# 34   Johannesburg -26.2044   28.0416     4434827   28.049722 -26.205000
# 35        Seattle  47.6211 -122.3244     3789215 -122.330062  47.603832
# 36      Cape Town -33.9250   18.4250      433688   18.417396 -33.928992
# 37        Abidjan   5.3364   -4.0267     4980000   -4.016107   5.320357
# 38      Ann Arbor  42.2755  -83.7312      322267  -83.731229  42.268157
# 39         London  51.5072   -0.1275    11120000   -0.127647  51.507322

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6092/3681542881.py in <module>
#       1 # Libraries/Modules import conventions
# ----> 2 from bokeh.io import output_notebook, show
#       3 from bokeh.plotting import figure, output_file, show
#
# ~\Anaconda3\lib\site-packages\bokeh\io\__init__.py in <module>
#      22
#      23 # Bokeh imports
# ---> 24 from .doc import curdoc
#      25 from .export import export_png, export_svg, export_svgs
#      26 from .notebook import install_jupyter_hooks, install_notebook_hook, push_notebook
#
# ~\Anaconda3\lib\site-packages\bokeh\io\doc.py in <module>
#      27
#      28 # Bokeh imports
# ---> 29 from .state import curstate
#      30
#      31 if TYPE_CHECKING:
#
# ~\Anaconda3\lib\site-packages\bokeh\io\state.py in <module>
#      51 # Bokeh imports
#      52 from ..core.types import PathLike
# ---> 53 from ..document import Document
#      54 from ..resources import Resources, ResourcesMode
#      55
#
# ~\Anaconda3\lib\site-packages\bokeh\document\__init__.py in <module>
#      48 #-----------------------------------------------------------------------------
#      49
# ---> 50 from .document import DEFAULT_TITLE ; DEFAULT_TITLE
#      51 from .document import Document ; Document
#      52 from .locking import without_document_lock ; without_document_lock
#
# ~\Anaconda3\lib\site-packages\bokeh\document\document.py in <module>
#      49
#      50 # External imports
# ---> 51 from jinja2 import Template
#      52
#      53 # Bokeh imports
#
# ~\Anaconda3\lib\site-packages\jinja2\__init__.py in <module>
#      10 from .bccache import FileSystemBytecodeCache
#      11 from .bccache import MemcachedBytecodeCache
# ---> 12 from .environment import Environment
#      13 from .environment import Template
#      14 from .exceptions import TemplateAssertionError
#
# ~\Anaconda3\lib\site-packages\jinja2\environment.py in <module>
#      23 from .compiler import CodeGenerator
#      24 from .compiler import generate
# ---> 25 from .defaults import BLOCK_END_STRING
#      26 from .defaults import BLOCK_START_STRING
#      27 from .defaults import COMMENT_END_STRING
#
# ~\Anaconda3\lib\site-packages\jinja2\defaults.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2 from ._compat import range_type
# ----> 3 from .filters import FILTERS as DEFAULT_FILTERS  # noqa: F401
#       4 from .tests import TESTS as DEFAULT_TESTS  # noqa: F401
#       5 from .utils import Cycler
#
# ~\Anaconda3\lib\site-packages\jinja2\filters.py in <module>
#      11 from markupsafe import escape
#      12 from markupsafe import Markup
# ---> 13 from markupsafe import soft_unicode
#      14
#      15 from ._compat import abc
#
# ImportError: cannot import name 'soft_unicode' from 'markupsafe' (C:\Users\cparker\Anaconda3\lib\site-packages\markupsafe\__init__.py)
